# %% [markdown]
# # Food Deserts Model Implementation
#
# Group Members: Nathan Deron, Jeremiah Humes, Devraj Kori, Meredith Meadows

# %% [markdown]
# ## Setup

# %%
# Import packages
from gurobipy import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Load in the data
vacant_lots = pd.read_csv('data/vacant_lots_centroid.csv')
travel_times = pd.read_csv('data/travel_times_all.csv')
travel_costs = pd.read_csv('data/travel_costs_all.csv')
supermarkets = pd.read_csv('data/supermarkets.csv')
addresses = pd.read_csv('data/pittsburgh_all.csv')

# %%
#Extract the relevant variables and put into numpy arrays
D = travel_costs.iloc[:,2:].to_numpy(dtype = float)
T = travel_times.iloc[:,2:].to_numpy(dtype = float)

# %%
len(households)
# Out:
# 730

# %% [markdown]
# ## Define Parameters

# %%
#Create generators for variable indexes
households = range(len(D)) #indexed by i
store_type = range(3) #not sure about this one yet
location = range(T.shape[1]) #indexed by k, 0-60 = grocery stores, 61-99 = vacant lot

#Create O[k] - convenience store identifier
#Logic: len(supermarkets) is number of stores, get a list of ones of this length
#number of lots is number of columns in either travel_times or travel_costs minus number of stores
#since they are all columns in the same matrix, make a list of zeros of this size
#Add both lists together
number_of_stores = len(supermarkets)
number_of_lots = T.shape[1] - number_of_stores
#lots go first, which matches how routes were calculated
O = ([0]*number_of_lots)+([1]*number_of_stores)

#Create E[k] - the cost of building a store at location k
#estimated cost of building the store + the cost of acquiring the lot
#Construction cost = 17,000 sq ft * $78.57 per sq ft
constr_cost = 17000 * 78.57

#Get the lot prices
lot_prices = list(vacant_lots['LOCALLAND__asmt'])

#Create E[k] based on O[k] - doesn't matter what price for non-vacant areas set to
E = [constr_cost + lot_prices[i] for i in range(number_of_lots)]+[9999999]*number_of_stores


#Define the lambda penalty

#Generate store preference for each household
#Separate by each third of the income distribution
addresses['prefs'] = pd.qcut(addresses['simulated_income'], 3, labels = [1, 2, 3])

lambda_penalty = 20
lamb = []
for i in households:
    pref = [lambda_penalty if addresses['prefs'][i] != j else 0 for j in store_type]
    lamb.append(pref)
lamb = np.array(lamb)

# Construct Z[i,k] = 1 if household travels time exceeds 20 minutes, 0 otherwise
# travel time is in hours, so convert 20 minutes to hours
cutoff = 20
cutoff_hours = cutoff/60

#Take travel times, replace any value greater than the cuttoff with 1, 0 otherwise
Z = np.where(T > cutoff_hours, 1, 0)

#Construct the delta matrix
#Difference between cutoff and travel time
Z = (T - cutoff_hours)*Z

#Finally, convert Z to minutes
Z = Z*60

#Set Delta penalty
delta = 2

# %% [markdown]
# ## Gurobi Implementation - Decision Vars, Objective Terms, and Constraints

# %%
#Initialize the model
m = Model(name = 'Food_Deserts')

#Define decision variables
X = m.addVars(store_type, location, vtype = GRB.BINARY, name = 'X_jk')
Y = m.addVars(households, store_type, location, vtype = GRB.BINARY, name = 'Y_ijk')

#Define the objective terms
#Total Construction cost
BUILD_COST = LinExpr()

for j in store_type:
    for k in location:
        BUILD_COST += X[j,k]*E[k]
        
#Total Access cost
ACCESS_COST = LinExpr()

for j in store_type:
    for i in households:
        for k in location:
            ACCESS_COST += Y[i,j,k] * (D[i,k] + Z[i,k]*delta + lamb[i,j]) * 52

#Define the constraints

#Can only build on vacant land

for j in store_type:
    for k in location:
        m.addConstr(X[j,k] <= 1 - O[k])

#Can only build one store on each lot k
for k in location:
    m.addConstr(sum(X[j,k] for j in store_type) <=1)

#Can only shop at existing or built store
for i in households:
    for j in store_type:
        for k in location:
            m.addConstr(Y[i,j,k] <= O[k] + X[j,k])

#must build 5 stores
#m.addConstr( sum(X[j,k] for j in store_type for k in location) >= 5)

#Customer assignment
for i in households:
    m.addConstr( sum(Y[i,j,k] for j in store_type for k in location) == 1 )

# %% [markdown]
# ## Add Goals Weights, Set Objective, and Solve

# %%
#Initialize an empty list to store tuples
#tuple = (construction cost, access cost)
results = []

#Define alpha values to use
step = 0.002
alphas = np.arange(0, 1+step, step)

for alpha in alphas:
    #
    m.setObjective((alpha*BUILD_COST/len(households)) + (52*2*(1-alpha)*ACCESS_COST/len(households)), GRB.MINIMIZE)
    m.setParam('OutputFlag', 0)
    m.optimize()
    results.append((BUILD_COST.getValue(), ACCESS_COST.getValue()))
    print('Alpha: ', str(alpha))
    print('Optimal Construction Cost: ', str(round(BUILD_COST.getValue(), 2)))
    print('Optimal Access Cost: ', str(round(ACCESS_COST.getValue(), 2)))
    print('Total Objective Function Value: ', str(round(m.objVal, 2)))
    print('Stores built: ',str(sum(X[(j,k)].x for j in store_type for k in location)))
    print()
# Out:
# Alpha:  0.0
# Optimal Construction Cost:  1032945270.0
# Optimal Access Cost:  6280.04
# Total Objective Function Value:  894.69
# Stores built:  756.0
#
# Alpha:  0.002
# Optimal Construction Cost:  12122610.0
# Optimal Access Cost:  6692.73
# Total Objective Function Value:  984.79
# Stores built:  9.0
#
# Alpha:  0.004
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  6952.49
# Total Objective Function Value:  1001.33
# Stores built:  2.0
#
# Alpha:  0.006
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  6952.49
# Total Objective Function Value:  1006.75
# Stores built:  2.0
#
# Alpha:  0.008
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  1008.36
# Stores built:  0.0
#
# Alpha:  0.01
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  1006.33
# Stores built:  0.0
#
# Alpha:  0.012
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  1004.29
# Stores built:  0.0
#
# Alpha:  0.014
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  1002.26
# Stores built:  0.0
#
# Alpha:  0.016
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  1000.23
# Stores built:  0.0
#
# Alpha:  0.018000000000000002
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  998.2
# Stores built:  0.0
#
# Alpha:  0.02
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  996.16
# Stores built:  0.0
#
# Alpha:  0.022
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  994.13
# Stores built:  0.0
#
# Alpha:  0.024
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  992.1
# Stores built:  0.0
#
# Alpha:  0.026000000000000002
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  990.06
# Stores built:  0.0
#
# Alpha:  0.028
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  988.03
# Stores built:  0.0
#
# Alpha:  0.03
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  986.0
# Stores built:  0.0
#
# Alpha:  0.032
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  983.96
# Stores built:  0.0
#
# Alpha:  0.034
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  981.93
# Stores built:  0.0
#
# Alpha:  0.036000000000000004
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  979.9
# Stores built:  0.0
#
# Alpha:  0.038
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  977.87
# Stores built:  0.0
#
# Alpha:  0.04
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  975.83
# Stores built:  0.0
#
# Alpha:  0.042
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  973.8
# Stores built:  0.0
#
# Alpha:  0.044
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  971.77
# Stores built:  0.0
#
# Alpha:  0.046
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  969.73
# Stores built:  0.0
#
# Alpha:  0.048
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  967.7
# Stores built:  0.0
#
# Alpha:  0.05
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  965.67
# Stores built:  0.0
#
# Alpha:  0.052000000000000005
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  963.64
# Stores built:  0.0
#
# Alpha:  0.054
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  961.6
# Stores built:  0.0
#
# Alpha:  0.056
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  959.57
# Stores built:  0.0
#
# Alpha:  0.058
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  957.54
# Stores built:  0.0
#
# Alpha:  0.06
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  955.5
# Stores built:  0.0
#
# Alpha:  0.062
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  953.47
# Stores built:  0.0
#
# Alpha:  0.064
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  951.44
# Stores built:  0.0
#
# Alpha:  0.066
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  949.4
# Stores built:  0.0
#
# Alpha:  0.068
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  947.37
# Stores built:  0.0
#
# Alpha:  0.07
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  945.34
# Stores built:  0.0
#
# Alpha:  0.07200000000000001
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  943.31
# Stores built:  0.0
#
# Alpha:  0.074
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  941.27
# Stores built:  0.0
#
# Alpha:  0.076
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  939.24
# Stores built:  0.0
#
# Alpha:  0.078
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  937.21
# Stores built:  0.0
#
# Alpha:  0.08
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  935.17
# Stores built:  0.0
#
# Alpha:  0.082
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  933.14
# Stores built:  0.0
#
# Alpha:  0.084
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  931.11
# Stores built:  0.0
#
# Alpha:  0.08600000000000001
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  929.07
# Stores built:  0.0
#
# Alpha:  0.088
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  927.04
# Stores built:  0.0
#
# Alpha:  0.09
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  925.01
# Stores built:  0.0
#
# Alpha:  0.092
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  922.98
# Stores built:  0.0
#
# Alpha:  0.094
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  920.94
# Stores built:  0.0
#
# Alpha:  0.096
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  918.91
# Stores built:  0.0
#
# Alpha:  0.098
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  7135.0
# Total Objective Function Value:  916.88
# Stores built:  0.0
#
# Alpha:  0.1
# Optimal Construction Cost:  0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-128-f22872a0caea> in <module>
#      15     print('Alpha: ', str(alpha))
#      16     print('Optimal Construction Cost: ', str(round(BUILD_COST.getValue(), 2)))
# ---> 17     print('Optimal Access Cost: ', str(round(ACCESS_COST.getValue(), 2)))
#      18     print('Total Objective Function Value: ', str(round(m.objVal, 2)))
#      19     print('Stores built: ',str(sum(X[(j,k)].x for j in store_type for k in location)))
#
# KeyboardInterrupt:

# %% [markdown]
# # Results - Plot Pareto Frontier

# %%
#Get x and y vectors from the results
x = [BUILD_COST for (BUILD_COST, ACCESS_COST) in results]
y = [ACCESS_COST for (BUILD_COST, ACCESS_COST) in results]

#Plot the results
#plt.plot(x,y)
plt.scatter(x,y)
plt.title('Pareto Frontier - Per Capita Construction Cost vs. Annual Access Cost')
plt.xlabel('Per Capita Construction Cost (USD)')
plt.ylabel('Average Annual Access Cost (USD)')
# Out:
# Text(0, 0.5, 'Total Access Cost (USD)')

# %%
sum(Y[(i,j,k)].x for i in households for j in store_type for k in location)
# Out:
# 730.0
