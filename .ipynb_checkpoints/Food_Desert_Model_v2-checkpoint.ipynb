# %% [markdown]
# # Food Deserts Model Implementation
#
# Group Members: Nathan Deron, Jeremiah Humes, Devraj Kori, Meredith Meadows

# %% [markdown]
# ## Setup

# %%
# Import packages
from gurobipy import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Load in the data
vacant_lots = pd.read_csv('data/vacant_lots_centroid.csv')
travel_times = pd.read_csv('data/travel_times_all.csv')
travel_costs = pd.read_csv('data/travel_costs_all.csv')
supermarkets = pd.read_csv('data/supermarkets.csv')
addresses = pd.read_csv('data/pittsburgh_all.csv')

# %%
#Extract the relevant variables and put into numpy arrays
D = travel_costs.iloc[:,2:].to_numpy(dtype = float)
T = travel_times.iloc[:,2:].to_numpy(dtype = float)

# %%
len(households)
# Out:
# 730

# %% [markdown]
# ## Define Parameters

# %%
#Create generators for variable indexes
households = range(len(D)) #indexed by i
store_type = range(3) #not sure about this one yet
location = range(T.shape[1]) #indexed by k, 0-60 = grocery stores, 61-99 = vacant lot

#Create O[k] - convenience store identifier
#Logic: len(supermarkets) is number of stores, get a list of ones of this length
#number of lots is number of columns in either travel_times or travel_costs minus number of stores
#since they are all columns in the same matrix, make a list of zeros of this size
#Add both lists together
number_of_stores = len(supermarkets)
number_of_lots = T.shape[1] - number_of_stores
#lots go first, which matches how routes were calculated
O = ([0]*number_of_lots)+([1]*number_of_stores)

#Create E[k] - the cost of building a store at location k
#estimated cost of building the store + the cost of acquiring the lot
#Construction cost = 17,000 sq ft * $78.57 per sq ft
constr_cost = 17000 * 78.57

#Get the lot prices
lot_prices = list(vacant_lots['LOCALLAND__asmt'])

#Create E[k] based on O[k] - doesn't matter what price for non-vacant areas set to
E = [constr_cost + lot_prices[i] for i in range(number_of_lots)]+[9999999]*number_of_stores


#Define the lambda penalty

#Generate store preference for each household
#Separate by each third of the income distribution
addresses['prefs'] = pd.qcut(addresses['simulated_income'], 3, labels = [1, 2, 3])

lambda_penalty = 20
lamb = []
for i in households:
    pref = [lambda_penalty if addresses['prefs'][i] != j else 0 for j in store_type]
    lamb.append(pref)
lamb = np.array(lamb)

# Construct Z[i,k] = 1 if household travels time exceeds 20 minutes, 0 otherwise
# travel time is in hours, so convert 20 minutes to hours
cutoff = 20
cutoff_hours = cutoff/60

#Take travel times, replace any value greater than the cuttoff with 1, 0 otherwise
Z = np.where(T > cutoff_hours, 1, 0)

#Construct the delta matrix
#Difference between cutoff and travel time
Z = (T - cutoff_hours)*Z

#Finally, convert Z to minutes
Z = Z*60

#Set Delta penalty
delta = 2

# %% [markdown]
# ## Gurobi Implementation - Decision Vars, Objective Terms, and Constraints

# %%
#Initialize the model
m = Model(name = 'Food_Deserts')

#Define decision variables
X = m.addVars(store_type, location, vtype = GRB.BINARY, name = 'X_jk')
Y = m.addVars(households, store_type, location, vtype = GRB.BINARY, name = 'Y_ijk')

#Define the objective terms
#Total Construction cost
BUILD_COST = LinExpr()

for j in store_type:
    for k in location:
        BUILD_COST += X[j,k]*E[k]
        
#Total Access cost
ACCESS_COST = LinExpr()

for j in store_type:
    for i in households:
        for k in location:
            ACCESS_COST += Y[i,j,k] * (D[i,k] + Z[i,k]*delta + lamb[i,j]) * 52 * 2

#Define the constraints

#Can only build on vacant land

for j in store_type:
    for k in location:
        m.addConstr(X[j,k] <= 1 - O[k])

#Can only build one store on each lot k
for k in location:
    m.addConstr(sum(X[j,k] for j in store_type) <=1)

#Can only shop at existing or built store
for i in households:
    for j in store_type:
        for k in location:
            m.addConstr(Y[i,j,k] <= O[k] + X[j,k])

#build max of 5 stores
m.addConstr( sum(X[j,k] for j in store_type for k in location) <= 5)

#Customer assignment
for i in households:
    m.addConstr( sum(Y[i,j,k] for j in store_type for k in location) == 1 )

# %% [markdown]
# ## Add Goals Weights, Set Objective, and Solve

# %%
#Initialize an empty list to store tuples
#tuple = (construction cost, access cost)
results = []

#Define alpha values to use
step = 0.0001
alphas = np.arange(0, 1+step, step)

counter = 0
for alpha in alphas:
    #add this condition so the for loop breaks if the alpha is high enough to stop building stores
    if counter==0 or sum(X[(j,k)].x for j in store_type for k in location)>0:
        counter+=1
        m.setObjective((alpha*BUILD_COST/len(households)) + ((1-alpha)*ACCESS_COST/len(households)), GRB.MINIMIZE)
        m.setParam('OutputFlag', 0)
        m.optimize()
        results.append((BUILD_COST.getValue()/len(households),
                        ACCESS_COST.getValue()/len(households),
                        str(sum(X[(j,k)].x for j in store_type for k in location))))
        print('Alpha: ', str(alpha))
        print('Optimal Construction Cost: ', str(round(BUILD_COST.getValue(), 2)))
        print('Optimal Access Cost: ', str(round(ACCESS_COST.getValue(), 2)))
        print('Total Objective Function Value: ', str(round(m.objVal, 2)))
        print('Stores built: ',str(sum(X[(j,k)].x for j in store_type for k in location)))
        print()
# Out:
# Alpha:  0.0
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  970.66
# Stores built:  5.0
#
# Alpha:  0.0001
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  971.49
# Stores built:  5.0
#
# Alpha:  0.0002
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  972.32
# Stores built:  5.0
#
# Alpha:  0.00030000000000000003
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  973.15
# Stores built:  5.0
#
# Alpha:  0.0004
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  973.98
# Stores built:  5.0
#
# Alpha:  0.0005
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  974.81
# Stores built:  5.0
#
# Alpha:  0.0006000000000000001
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  975.64
# Stores built:  5.0
#
# Alpha:  0.0007
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  976.48
# Stores built:  5.0
#
# Alpha:  0.0008
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  977.31
# Stores built:  5.0
#
# Alpha:  0.0009000000000000001
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  978.14
# Stores built:  5.0
#
# Alpha:  0.001
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  978.97
# Stores built:  5.0
#
# Alpha:  0.0011
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  979.8
# Stores built:  5.0
#
# Alpha:  0.0012000000000000001
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  980.63
# Stores built:  5.0
#
# Alpha:  0.0013000000000000002
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  981.46
# Stores built:  5.0
#
# Alpha:  0.0014
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  982.29
# Stores built:  5.0
#
# Alpha:  0.0015
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  983.12
# Stores built:  5.0
#
# Alpha:  0.0016
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  983.95
# Stores built:  5.0
#
# Alpha:  0.0017000000000000001
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  984.78
# Stores built:  5.0
#
# Alpha:  0.0018000000000000002
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  985.62
# Stores built:  5.0
#
# Alpha:  0.0019
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  986.45
# Stores built:  5.0
#
# Alpha:  0.002
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  987.28
# Stores built:  5.0
#
# Alpha:  0.0021000000000000003
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  988.11
# Stores built:  5.0
#
# Alpha:  0.0022
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  988.94
# Stores built:  5.0
#
# Alpha:  0.0023
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  989.77
# Stores built:  5.0
#
# Alpha:  0.0024000000000000002
# Optimal Construction Cost:  6774150.0
# Optimal Access Cost:  708581.26
# Total Objective Function Value:  990.6
# Stores built:  5.0
#
# Alpha:  0.0025
# Optimal Construction Cost:  6724550.0
# Optimal Access Cost:  708701.2
# Total Objective Function Value:  991.43
# Stores built:  5.0
#
# Alpha:  0.0026000000000000003
# Optimal Construction Cost:  6724550.0
# Optimal Access Cost:  708701.2
# Total Objective Function Value:  992.25
# Stores built:  5.0
#
# Alpha:  0.0027
# Optimal Construction Cost:  6724550.0
# Optimal Access Cost:  708701.2
# Total Objective Function Value:  993.07
# Stores built:  5.0
#
# Alpha:  0.0028
# Optimal Construction Cost:  6724550.0
# Optimal Access Cost:  708701.2
# Total Objective Function Value:  993.9
# Stores built:  5.0
#
# Alpha:  0.0029000000000000002
# Optimal Construction Cost:  6724550.0
# Optimal Access Cost:  708701.2
# Total Objective Function Value:  994.72
# Stores built:  5.0
#
# Alpha:  0.003
# Optimal Construction Cost:  6724550.0
# Optimal Access Cost:  708701.2
# Total Objective Function Value:  995.55
# Stores built:  5.0
#
# Alpha:  0.0031000000000000003
# Optimal Construction Cost:  6724550.0
# Optimal Access Cost:  708701.2
# Total Objective Function Value:  996.37
# Stores built:  5.0
#
# Alpha:  0.0032
# Optimal Construction Cost:  6724550.0
# Optimal Access Cost:  708701.2
# Total Objective Function Value:  997.19
# Stores built:  5.0
#
# Alpha:  0.0033
# Optimal Construction Cost:  6724550.0
# Optimal Access Cost:  708701.2
# Total Objective Function Value:  998.02
# Stores built:  5.0
#
# Alpha:  0.0034000000000000002
# Optimal Construction Cost:  5384660.0
# Optimal Access Cost:  713211.76
# Total Objective Function Value:  998.76
# Stores built:  4.0
#
# Alpha:  0.0035
# Optimal Construction Cost:  4038470.0
# Optimal Access Cost:  717880.62
# Total Objective Function Value:  999.32
# Stores built:  3.0
#
# Alpha:  0.0036000000000000003
# Optimal Construction Cost:  4038470.0
# Optimal Access Cost:  717880.62
# Total Objective Function Value:  999.77
# Stores built:  3.0
#
# Alpha:  0.0037
# Optimal Construction Cost:  4038470.0
# Optimal Access Cost:  717880.62
# Total Objective Function Value:  1000.23
# Stores built:  3.0
#
# Alpha:  0.0038
# Optimal Construction Cost:  4038470.0
# Optimal Access Cost:  717880.62
# Total Objective Function Value:  1000.68
# Stores built:  3.0
#
# Alpha:  0.0039000000000000003
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1001.06
# Stores built:  2.0
#
# Alpha:  0.004
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1001.33
# Stores built:  2.0
#
# Alpha:  0.0041
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1001.61
# Stores built:  2.0
#
# Alpha:  0.004200000000000001
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1001.88
# Stores built:  2.0
#
# Alpha:  0.0043
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1002.15
# Stores built:  2.0
#
# Alpha:  0.0044
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1002.42
# Stores built:  2.0
#
# Alpha:  0.0045000000000000005
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1002.69
# Stores built:  2.0
#
# Alpha:  0.0046
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1002.96
# Stores built:  2.0
#
# Alpha:  0.0047
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1003.23
# Stores built:  2.0
#
# Alpha:  0.0048000000000000004
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1003.5
# Stores built:  2.0
#
# Alpha:  0.0049
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1003.77
# Stores built:  2.0
#
# Alpha:  0.005
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1004.04
# Stores built:  2.0
#
# Alpha:  0.0051
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1004.32
# Stores built:  2.0
#
# Alpha:  0.005200000000000001
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1004.59
# Stores built:  2.0
#
# Alpha:  0.0053
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1004.86
# Stores built:  2.0
#
# Alpha:  0.0054
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1005.13
# Stores built:  2.0
# Alpha:  0.0055000000000000005
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1005.4
# Stores built:  2.0
#
# Alpha:  0.0056
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1005.67
# Stores built:  2.0
#
# Alpha:  0.0057
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1005.94
# Stores built:  2.0
#
# Alpha:  0.0058000000000000005
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1006.21
# Stores built:  2.0
#
# Alpha:  0.0059
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1006.48
# Stores built:  2.0
#
# Alpha:  0.006
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1006.75
# Stores built:  2.0
#
# Alpha:  0.0061
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1007.03
# Stores built:  2.0
#
# Alpha:  0.006200000000000001
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1007.3
# Stores built:  2.0
#
# Alpha:  0.0063
# Optimal Construction Cost:  2701680.0
# Optimal Access Cost:  723059.35
# Total Objective Function Value:  1007.57
# Stores built:  2.0
#
# Alpha:  0.0064
# Optimal Construction Cost:  1336690.0
# Optimal Access Cost:  731772.34
# Total Objective Function Value:  1007.73
# Stores built:  1.0
#
# Alpha:  0.006500000000000001
# Optimal Construction Cost:  1336690.0
# Optimal Access Cost:  731772.34
# Total Objective Function Value:  1007.81
# Stores built:  1.0
#
# Alpha:  0.0066
# Optimal Construction Cost:  1336690.0
# Optimal Access Cost:  731772.34
# Total Objective Function Value:  1007.9
# Stores built:  1.0
#
# Alpha:  0.0067
# Optimal Construction Cost:  1336690.0
# Optimal Access Cost:  731772.34
# Total Objective Function Value:  1007.98
# Stores built:  1.0
#
# Alpha:  0.0068000000000000005
# Optimal Construction Cost:  1336690.0
# Optimal Access Cost:  731772.34
# Total Objective Function Value:  1008.06
# Stores built:  1.0
#
# Alpha:  0.006900000000000001
# Optimal Construction Cost:  1336690.0
# Optimal Access Cost:  731772.34
# Total Objective Function Value:  1008.15
# Stores built:  1.0
#
# Alpha:  0.007
# Optimal Construction Cost:  1336690.0
# Optimal Access Cost:  731772.34
# Total Objective Function Value:  1008.23
# Stores built:  1.0
#
# Alpha:  0.0071
# Optimal Construction Cost:  1336690.0
# Optimal Access Cost:  731772.34
# Total Objective Function Value:  1008.31
# Stores built:  1.0
#
# Alpha:  0.007200000000000001
# Optimal Construction Cost:  1336690.0
# Optimal Access Cost:  731772.34
# Total Objective Function Value:  1008.39
# Stores built:  1.0
#
# Alpha:  0.0073
# Optimal Construction Cost:  1336690.0
# Optimal Access Cost:  731772.34
# Total Objective Function Value:  1008.48
# Stores built:  1.0
#
# Alpha:  0.0074
# Optimal Construction Cost:  1336690.0
# Optimal Access Cost:  731772.34
# Total Objective Function Value:  1008.56
# Stores built:  1.0
#
# Alpha:  0.007500000000000001
# Optimal Construction Cost:  1336690.0
# Optimal Access Cost:  731772.34
# Total Objective Function Value:  1008.64
# Stores built:  1.0
#
# Alpha:  0.0076
# Optimal Construction Cost:  1336690.0
# Optimal Access Cost:  731772.34
# Total Objective Function Value:  1008.73
# Stores built:  1.0
#
# Alpha:  0.0077
# Optimal Construction Cost:  0.0
# Optimal Access Cost:  742039.68
# Total Objective Function Value:  1008.67
# Stores built:  0.0

# %% [markdown]
# # Results - Plot Pareto Frontier

# %%
#Get x and y vectors from the results
x = [BUILD_COST for (BUILD_COST, ACCESS_COST, stores_built) in results]
y = [ACCESS_COST for (BUILD_COST, ACCESS_COST,stores_built) in results]
c = [int(float(stores_built)) for (BUILD_COST, ACCESS_COST,stores_built) in results]
#Plot the results
plt.plot(x,y)
plt.scatter(x,y,c=c)
plt.title('Pareto Frontier - Per Capita Construction Cost vs. Annual Access Cost')
plt.xlabel('Per Capita Construction Cost (USD)')
plt.ylabel('Average Annual Access Cost (USD)')
# Out:
# Text(0, 0.5, 'Average Annual Access Cost (USD)')

# %%
#identify stores built in the optimal solution for alpha = .001

alpha = .001
m.setObjective((alpha*BUILD_COST/len(households)) + ((1-alpha)*ACCESS_COST/len(households)), GRB.MINIMIZE)
m.setParam('OutputFlag', 0)
m.optimize()

stores_built = []
for j in store_type:
    for k in location:
        if X[(j,k)].x==1:
            stores_built.append(k)
vacant_lots.iloc[stores_built]
# Out:
#              X          Y  FAIRMARKETBUILDING__asmt  PROPERTYZIP__asmt  \
# 144 -80.015352  40.397058                         0              15226
# 7   -80.002595  40.402214                         0              15226
# 64  -79.919878  40.371337                         0              15207
# 91  -79.873725  40.455854                         0              15221
# 118 -79.904468  40.422769                         0              15218
#
#      FAIRMARKETLAND__asmt SALECODE__asmt  \
# 144                  1000              3
# 7                    4200              N
# 64                  29300              H
# 91                  60100              N
# 118                  1100              H
#
#                                           LEGAL1__asmt PROPERTYFRACTION__asmt  \
# 144    W C STILLWAGON PLAN BLK M & N 1.92 A LD EDGEWOO
# 7      IRREG LOT 218.94X218.26X221.52 TIMBERLAND AVE
# 64                                KENNEDY PLAN OF LOTS
# 91   EAST HILLS PARK 1ST PLAN STAGE 1 2 & 3 (18.716...
# 118    YE OLDE SWISSVALE FARME 1ST ADDN PLAN PT 14 LOT
#
#                   PIN NEIGHDESC__asmt  ...  PROPERTYCITY__asmt  \
# 144  0061J00088000000           11903  ...          PITTSBURGH
# 7    0061D00065000000           11903  ...          PITTSBURGH
# 64   0185H00199000000           13102  ...          PITTSBURGH
# 91   0231L00380000000           11301  ...          PITTSBURGH
# 118  0129C00200000000           11403  ...          PITTSBURGH
#
#     NEIGHCODE__asmt LOCALTOTAL__asmt SALEPRICE__asmt  COUNTYLAND__asmt  \
# 144           11903             1000             1.0              1000
# 7             11903             4200             0.0              4200
# 64            13102            29300         10000.0             29300
# 91            11301            60100             0.0             60100
# 118           11403             1100         50000.0              1100
#
#      PROPERTYSTATE__asmt LOCALBUILDING__asmt  USEDESC__asmt  \
# 144                   PA                   0    VACANT LAND
# 7                     PA                   0    VACANT LAND
# 64                    PA                   0    VACANT LAND
# 91                    PA                   0    VACANT LAND
# 118                   PA                   0    VACANT LAND
#
#      COUNTYTOTAL__asmt          MUNIDESC__asmt
# 144               1000  19th Ward - PITTSBURGH
# 7                 4200  19th Ward - PITTSBURGH
# 64               29300  31st Ward - PITTSBURGH
# 91               60100  13th Ward - PITTSBURGH
# 118               1100  14th Ward - PITTSBURGH
#
# [5 rows x 31 columns]

# %%
# Out:
# [144, 7, 64, 91, 118]

# %%
# Out:
# -0.0
